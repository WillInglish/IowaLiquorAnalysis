# %% [markdown]
# # Json Dictionary Visualization

# %%
#Importing libraries
import json

# %%
# Opening specified json file
with open (r'C:\Users\William Inglish\Project 6 Liquor Sales\02 Data\Original\IowaCounties.json') as access_json:
    read_content = json.load(access_json)

# %%
read_content
# Out:
# {'type': 'Topology',
#  'transform': {'scale': [0.0017669358765993605, 0.0012457790492015905],
#   'translate': [-96.62384631382284, 40.37865860641297]},
#  'arcs': [[[2448, 1540], [133, 0]],
#   [[2581, 1540], [132, 1]],
#   [[2713, 1541], [0, -350]],
#   [[2713, 1191], [-265, 1]],
#   [[2448, 1192], [0, 348]],
#   [[1218, 625], [130, 0]],
#   [[1348, 625], [129, 0]],
#   [[1477, 625], [-1, -209]],
#   [[1476, 416], [-258, 2]],
#   [[1218, 418], [0, 207]],
#   [[1234, 1819], [267, 0]],
#   [[1501, 1819], [0, -70]],
#   [[1501, 1749], [22, -69], [1, -210]],
#   [[1524, 1470], [-132, 0]],
#   [[1392, 1470], [-132, -1]],
#   [[1260, 1469], [0, 212], [-26, 0], [0, 69]],
#   [[1234, 1750], [0, 69]],
#   [[2713, 1191], [1, -281]],
#   [[2714, 910], [-66, -1]],
#   [[2648, 909], [-199, -1]],
#   [[2449, 908], [-1, 284]],
#   [[500, 1752], [200, 0]],
#   [[700, 1752], [0, -70], [37, 0], [-1, -212]],
#   [[736, 1470], [-196, 1]],
#   [[540, 1471], [1, 211], [-42, 0], [1, 70]],
# ...

# %%
# Selecting keys to subset dictionary
startkey = read_content['objects']['cb_2015_iowa_county_20m']['geometries']
startkey
# Out:
# [{'arcs': [[0, 1, 2, 3, 4]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '011',
#    'COUNTYNS': '00465195',
#    'AFFGEOID': '0500000US19011',
#    'GEOID': '19011',
#    'NAME': 'Benton',
#    'LSAD': '06',
#    'ALAND': 1855117304,
#    'AWATER': 5760770}},
#  {'arcs': [[5, 6, 7, 8, 9]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '175',
#    'COUNTYNS': '00465276',
#    'AFFGEOID': '0500000US19175',
#    'GEOID': '19175',
#    'NAME': 'Union',
#    'LSAD': '06',
#    'ALAND': 1097235771,
#    'AWATER': 5575853}},
#  {'arcs': [[10, 11, 12, 13, 14, 15, 16]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '187',
#    'COUNTYNS': '00465282',
#    'AFFGEOID': '0500000US19187',
#    'GEOID': '19187',
#    'NAME': 'Webster',
#    'LSAD': '06',
#    'ALAND': 1853443705,
#    'AWATER': 7277624}},
#  {'arcs': [[-4, 17, 18, 19, 20]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
# ...

# %%
startkey
# Out:
# [{'arcs': [[0, 1, 2, 3, 4]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '011',
#    'COUNTYNS': '00465195',
#    'AFFGEOID': '0500000US19011',
#    'GEOID': '19011',
#    'NAME': 'Benton',
#    'LSAD': '06',
#    'ALAND': 1855117304,
#    'AWATER': 5760770}},
#  {'arcs': [[5, 6, 7, 8, 9]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '175',
#    'COUNTYNS': '00465276',
#    'AFFGEOID': '0500000US19175',
#    'GEOID': '19175',
#    'NAME': 'Union',
#    'LSAD': '06',
#    'ALAND': 1097235771,
#    'AWATER': 5575853}},
#  {'arcs': [[10, 11, 12, 13, 14, 15, 16]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '187',
#    'COUNTYNS': '00465282',
#    'AFFGEOID': '0500000US19187',
#    'GEOID': '19187',
#    'NAME': 'Webster',
#    'LSAD': '06',
#    'ALAND': 1853443705,
#    'AWATER': 7277624}},
#  {'arcs': [[-4, 17, 18, 19, 20]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
# ...

# %%
# Looking for more dict keys
read_content['objects']['cb_2015_iowa_county_20m'].keys()
# Out:
# dict_keys(['type', 'geometries'])

# %%
type(startkey)
# Out:
# list

# %%
for county in startkey:
    print(county)
# Out:
# {'arcs': [[0, 1, 2, 3, 4]], 'type': 'Polygon', 'properties': {'STATEFP': '19', 'COUNTYFP': '011', 'COUNTYNS': '00465195', 'AFFGEOID': '0500000US19011', 'GEOID': '19011', 'NAME': 'Benton', 'LSAD': '06', 'ALAND': 1855117304, 'AWATER': 5760770}}
# {'arcs': [[5, 6, 7, 8, 9]], 'type': 'Polygon', 'properties': {'STATEFP': '19', 'COUNTYFP': '175', 'COUNTYNS': '00465276', 'AFFGEOID': '0500000US19175', 'GEOID': '19175', 'NAME': 'Union', 'LSAD': '06', 'ALAND': 1097235771, 'AWATER': 5575853}}
# {'arcs': [[10, 11, 12, 13, 14, 15, 16]], 'type': 'Polygon', 'properties': {'STATEFP': '19', 'COUNTYFP': '187', 'COUNTYNS': '00465282', 'AFFGEOID': '0500000US19187', 'GEOID': '19187', 'NAME': 'Webster', 'LSAD': '06', 'ALAND': 1853443705, 'AWATER': 7277624}}
# {'arcs': [[-4, 17, 18, 19, 20]], 'type': 'Polygon', 'properties': {'STATEFP': '19', 'COUNTYFP': '095', 'COUNTYNS': '00465236', 'AFFGEOID': '0500000US19095', 'GEOID': '19095', 'NAME': 'Iowa', 'LSAD': '06', 'ALAND': 1518916016, 'AWATER': 2686847}}
# ...

# %%
county.keys()
# Out:
# dict_keys(['arcs', 'type', 'properties'])

# %%
county['properties'].keys()
# Out:
# dict_keys(['STATEFP', 'COUNTYFP', 'COUNTYNS', 'AFFGEOID', 'GEOID', 'NAME', 'LSAD', 'ALAND', 'AWATER'])

# %%
c_list = []
for i in startkey:
    c_list.append(i)

# %%
c_list
# Out:
# [{'arcs': [[0, 1, 2, 3, 4]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '011',
#    'COUNTYNS': '00465195',
#    'AFFGEOID': '0500000US19011',
#    'GEOID': '19011',
#    'NAME': 'Benton',
#    'LSAD': '06',
#    'ALAND': 1855117304,
#    'AWATER': 5760770}},
#  {'arcs': [[5, 6, 7, 8, 9]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '175',
#    'COUNTYNS': '00465276',
#    'AFFGEOID': '0500000US19175',
#    'GEOID': '19175',
#    'NAME': 'Union',
#    'LSAD': '06',
#    'ALAND': 1097235771,
#    'AWATER': 5575853}},
#  {'arcs': [[10, 11, 12, 13, 14, 15, 16]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
#    'COUNTYFP': '187',
#    'COUNTYNS': '00465282',
#    'AFFGEOID': '0500000US19187',
#    'GEOID': '19187',
#    'NAME': 'Webster',
#    'LSAD': '06',
#    'ALAND': 1853443705,
#    'AWATER': 7277624}},
#  {'arcs': [[-4, 17, 18, 19, 20]],
#   'type': 'Polygon',
#   'properties': {'STATEFP': '19',
# ...
