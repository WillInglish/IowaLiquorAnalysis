# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# For displaying graphs

# %matplotlib inline

# %%
#Importing DF

path = r'C:\Users\William Inglish\Project 6 Liquor Sales'

df_sales = pd.read_csv(os.path.join(path,'02 Data', 'Prepared', 'Sales_Wrangled.csv'), index_col = 0)

# %%
df_sales.head()
# Out:
#   invoice_and_item_number        date  store_number  \
# 0         INV-33179700135  2021-01-04          2576
# 1         INV-33196200106  2021-01-04          2649
# 2         INV-33184300011  2021-01-04          2539
# 3         INV-33184100015  2021-01-04          4024
# 4         INV-33174200025  2021-01-04          5385
#
#                              store_name         address             city  \
# 0  Hy-Vee Wine and Spirits / Storm Lake  1250 N Lake St       Storm Lake
# 1                   Hy-Vee #3 / Dubuque   400 Locust St          Dubuque
# 2        Hy-Vee Food Store / Iowa Falls      640 S. Oak       Iowa Falls
# 3            Wal-Mart 1546 / Iowa Falls       840 S Oak       Iowa Falls
# 4                    Vine Food & Liquor   2704 Vine St.  West Des Moines
#
#    zip_code                        store_location  county_number county_name  \
# 0   50588.0  POINT (-95.200758 42.65318400000001)           11.0  BUENA VIST
# ...

# %%
df_sales.shape
# Out:
# (2805307, 24)

# %%
def remove_column_outliers(df, col):
    
    # IQR
    # Calculate the upper and lower limits
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR
 
    # Printing bounds
    print(col, '\nLower bound is: ', lower)
    print('Upper bound is: ', upper)
    print('Median is: ', df[col].median())
    print(df.shape, '\n')
    # Create arrays of Boolean values indicating the outlier rows
    upper_array = np.where(df[col]>=upper)[0]
    lower_array = np.where(df[col]<=lower)[0]
 
    # Removing the outliers
    df.drop(index=upper_array, inplace=True)
    df.drop(index=lower_array, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    #displaying boxplot of column without outliers
    # df.boxplot(column=[col])

# %%
for x in df_sales[['bottles_sold', 'sale_dollars', 'package_size', 'volume_sold_liters']]:
    remove_column_outliers(df_sales,x)
# Out:
# bottles_sold
# Lower bound is:  -10.5
# Upper bound is:  25.5
# Median is:  6.0
# (2258223, 24)
#
# sale_dollars
# Lower bound is:  -114.75
# Upper bound is:  299.25
# Median is:  81.0
# (2258223, 24)
#
# package_size
# Lower bound is:  -3.0
# Upper bound is:  21.0
# Median is:  12.0
# (2258223, 24)
#
# volume_sold_liters
# Lower bound is:  -9.75
# Upper bound is:  20.25
# Median is:  4.5
# (2258223, 24)
